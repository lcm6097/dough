# %%
transactions_path = "https://s3.amazonaws.com/www.yourdatasurfer.com/test_stock_transactions.csv"
investment_transactions = pd.read_csv(transactions_path)#.rename(columns={"Qty":"Quantity", "Open date":"Date"})
investment_transactions['Open date'] = pd.to_datetime(investment_transactions['Open date'])
investment_transactions['Cost_per_share'] = investment_transactions['Adj cost per share']
investment_transactions
# Out:
#    Symbol                   Security  Qty       Type  Open date  \
# 0    AMZN             AMAZON COM INC    4        Buy 2014-01-06
# 1      FB          FACEBOOK INC CL A   60        Buy 2014-01-06
# 2     GLW                CORNING INC  100        Buy 2014-01-06
# 3    GOOG          ALPHABET INC-CL C    2        Buy 2014-01-06
# 4   GOOGL          ALPHABET INC-CL A    2        Buy 2014-01-06
# 5     LNG            Cheniere Energy   30        Buy 2014-01-06
# 6      FB          FACEBOOK INC CL A   13        Buy 2014-01-29
# 7    TSLA                  TESLA INC   14        Buy 2014-02-18
# 8      FB          FACEBOOK INC CL A   17        Buy 2014-04-23
# 9    TSLA                  TESLA INC   12        Buy 2014-09-16
# 10     FB          FACEBOOK INC CL A    4        Buy 2014-12-31
# 11   AAPL                  APPLE INC   30        Buy 2015-08-26
# 12   NFLX                NETFLIX INC   10        Buy 2016-06-30
# 13   AMZN             AMAZON COM INC    3        Buy 2017-04-27
# 14    LNG            Cheniere Energy   30  Sell.FIFO 2017-09-15
# 15   NVDA         NVIDIA CORPORATION  100        Buy 2017-09-18
# 16   AAPL                  APPLE INC   22        Buy 2017-09-27
# 17   OSTK          OVERSTOCK COM INC  200        Buy 2017-10-30
# 18   BIDU              BAIDU INC ADS   40        Buy 2017-11-01
# 19   BABA  ALIBABA GROUP HOLDING LTD   20        Buy 2017-11-02
# 20   BABA  ALIBABA GROUP HOLDING LTD   40        Buy 2017-11-03
# 21     SQ            SQUARE INC CL A    1        Buy 2017-11-21
# 22     JD                 JD COM INC   10        Buy 2018-01-04
# 23     FB          FACEBOOK INC CL A   13  Sell.FIFO 2018-06-22
# 24     FB          FACEBOOK INC CL A    7  Sell.FIFO 2018-06-23
#
#     Adj cost per share  Adj cost  Cost_per_share
# 0              390.870   1563.48         390.870
# 1               54.790   3287.40          54.790
# 2               17.850   1784.99          17.850
# 3              554.580   1109.16         554.580
# 4              557.890   1115.77         557.890
# 5               42.870   1286.10          42.870
# 6               53.640    697.32          53.640
# 7              204.160   2858.24         204.160
# 8               61.710   1049.07          61.710
# 9              258.340   3100.08         258.340
# 10              78.860    315.44          78.860
# 11             106.790   3203.70         106.790
# 12              90.910    909.10          90.910
# 13             920.720   2762.15         920.720
# 14              43.640   1309.12          43.640
# 15             186.530  18652.56         186.530
# 16             154.660   3402.43         154.660
# 17              44.630   8926.95          44.630
# 18             251.130  10045.35         251.130
# 19             191.560   3831.15         191.560
# 20             186.690   7467.75         186.690
# 21              53.860     53.86          53.860
# 22              44.390    443.85          44.390
# 23             202.451   2631.86         202.451
# 24             202.450   1417.15         202.450

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data as wb
from datetime import datetime
from dateutil.relativedelta import relativedelta
from dateutil.parser import parser
from functools import cached_property, partial
import plotly.express as px
import re

class DataManipulation:
    def _subset_by_dates(self, df, start_date=None, end_date=None):
        if end_date is None:
            end_date = datetime.today()
        else:
            end_date = parser().parse(end_date)
        if start_date is None:
            start_date = end_date-relativedelta(years=5)
        else:
            start_date = parser().parse(start_date)
        return df[(df.index >= start_date)&(df.index <= end_date)]
    
    def _calculate_returns(self, df, start_date=None, end_date=None, log=False):
        df = self._subset_by_dates(df, start_date, end_date)
        if log is True:
            return np.log(df.pct_change()+1)
        else:
            return df.pct_change()
    
    def _get_market_data(self, start_date=None, end_date=None, market_ticker="^GSPC"):
        return wb.DataReader(market_ticker, data_source='yahoo',
                                             start='1970-1-1')['Close']
    
    def _lookup_values(self, df, column, value, condition="eq", to_="array"):
        is_col_index = True if (column == df.index.name)|(column == "index") else False
        if is_col_index:
            if condition == "gt":
                sub = df[df.index>=value]
            elif condition == "lt":
                sub = df[df.index<=value]
            else:
                sub = df[df.index==value]
        else:
            if condition == "gt":
                sub = df[df[column]>=value]
            elif condition == "lt":
                sub = df[df[column]<=value]
            else:
                sub = df[df[column]==value]
                
        if to_ == "array":
            if is_col_index:
                return sub.index.values
            else:
                return sub[column].values
        elif to_ == "df":
            return sub
        elif to_ == "series":
            if is_col_index:
                return sub.index
            else:
                return sub[column]
        elif to_ == "single":
            if is_col_index:
                return sub.index.values[0]
            else:
                return sub[column].values[0]
        else:
            if is_col_index:
                return list(sub.index.values)
            else:
                return list(sub[column].values)
        
    def _get_relative_date(self, time="5M", end=datetime.today()):
        result = end
        if "Y" in time:
            result = result-relativedelta(years=int(time[time.find("Y")-1]))
        if "M" in time:
            result = result-relativedelta(months=int(time[time.find("M")-1]))
            
        return result.strftime("%Y-%m-%d")

# %%
class Stock(DataManipulation):
    def __init__(self,ticker):
        self.symbol = ticker
        self.historical_data = pd.DataFrame()
        self.historical_data[ticker] = wb.DataReader(self.symbol, data_source='yahoo',
                                             start='1970-1-1')['Close']
    
    def volatility(self):
        # Assumes 5 year volatility
        five_years_ago = (datetime.today()-relativedelta(years=5)).strftime("%Y-%m-%d")
        tday = datetime.today().strftime("%Y-%m-%d")
        temp_df = self._subset_by_dates(self.historical_data, 
                                   five_years_ago, tday)
        temp_var = temp_df.values.std()
        return temp_var
    
    def _get_price(self, date):
        if date == "today":
            date = datetime.today()
        else:
            date = parser().parse(date)
        return self.historical_data.loc[self.historical_data.index == date, self.symbol].values[0]
    
    def plot(self, start_date=None, end_date=None):
        temp_df = self._subset_by_dates(self.historical_data, start_date, end_date)
        fig = px.line(temp_df, title=f"{self.symbol} Stock Price")
        return fig.show()
    
    def plot_returns(self, start_date=None, end_date=None):
        temp_df = self._calculate_returns(
                    self._subset_by_dates(
                        self.historical_data, start_date, end_date))
        return px.line(temp_df).show()
            
    def compare_to_market(self, start_date=None, end_date=None, market_ticker="^GSPC"):
        market_df = pd.DataFrame()
        market_df[market_ticker] = self._subset_by_dates(self._get_market_data(market_ticker),start_date,end_date)
        df = self._subset_by_dates(self.historical_data, start_date, end_date) 
        mx = df.join(market_df)
        temp_df = mx/mx.iloc[0]
        return px.line(temp_df, labels={'x':market_ticker}).show()
    
    def moving_average(self, *days, start_date=None, end_date=None):
        pd.options.mode.chained_assignment = None
        temp_df = self._subset_by_dates(self.historical_data, start_date, end_date)
        for d in days:
            temp_df[f"MA {d} days"] = temp_df[self.symbol].rolling(d, min_periods=1).mean()
        return px.line(temp_df)               
        
    def exponential_weighted(self, span=30, start_date=None, end_date=None, **kwargs):
        temp_df = self._subset_by_dates(self.historical_data, start_date, end_date)
        temp_df[f"{span} day EWA"] = temp_df[self.symbol].ewm(span=span,min_periods=0,adjust=False,ignore_na=False).mean()
        return px.line(temp_df)
    
    def macd(self):
        ma26 = self.historical_data[self.symbol].ewm(span=26,min_periods=0,adjust=False,ignore_na=False).mean()
        ma12 = self.historical_data[self.symbol].ewm(span=12,min_periods=0,adjust=False,ignore_na=False).mean()
        macd = pd.DataFrame()
        macd[f"MACD {self.symbol}"] = ma12 - ma26
        macd["Signal Line"] = macd[f"MACD {self.symbol}"].ewm(span=9,min_periods=0,adjust=False,ignore_na=False).mean()
        macd["Delta"] = macd[f"MACD {self.symbol}"] - macd["Signal Line"]
        temp_df = self._subset_by_dates(macd, start_date=self._get_relative_date("5M"))
        return px.line(temp_df)

# %%
abmd = Stock("ABMD")

# %%
dm = DataManipulation()
dm._lookup_values(abmd.historical_data, abmd.symbol, )

# %%
class Transaction(DataManipulation):
    def __init__(self, symbol, date, buy_quantity, price=None):
        self._stock = Stock(symbol)
        self._first_purchase_date = date
        self.shares = buy_quantity
        price_on_date = self._stock._get_price(date)
        if price is None:
            total_invested = buy_quantity*price_on_date
        else:
            total_indested = buy_quantity*price
        self.transaction = pd.DataFrame({
            "Symbol": [symbol],
            "Date": [date],
            "Price_on_Date": [price_on_date],
            "Shares_Owned": [buy_quantity],
            "Invested": [total_invested],
            "Market_Value": [buy_quantity*price_on_date],
            "Gain/Loss":[total_invested - (buy_quantity*price_on_date)]
        })
        
    def _get_market_dates_until(self, date):
        return self._subset_by_dates(self._stock.historical_data, 
                                     self._first_purchase_date, 
                                     date).rename(columns={self._stock.symbol:"Close_Price"})
    
#     def update_transaction(self, date):

# %%
trans = Transaction("AAPL","2019-1-2",10)

# %%
trans.transaction
# Out:
#   Symbol      Date  Price_on_Date  Shares_Owned    Invested  Market_Value  \
# 0   AAPL  2019-1-2          39.48            10  394.799995    394.799995
#
#    Gain/Loss
# 0        0.0

# %%
class Position(DataManipulation):
    def __init__(self, Stock):
        self._stock = Stock
        self._symbol = Stock.symbol
        self._historical_stock_data = self._stock.historical_data
        self.shares_owned = 0
        self.invested = 0
        self.market_value = 0
        self.transaction_history = pd.DataFrame(columns=["Symbol","Qty","Date","Type","Cost_per_share"])
        
    def buy(self, quantity, date, price=None):
        if price is None:
            price = self._subset_by_dates(self._historical_stock_data, date, date)[self._symbol].values[0]
        self.shares_owned += quantity
        self.invested += quantity*price
        pass
    
    def update(self, date):
        pass
    
    def sell(self, quantity, date, price=None):
        if price is None:
            print(f"You do not own enough shares of {self._stock.symbol} to sell {quantity} shares on {date}.\nPosition will be updated.")
            return self.update(date)
        
    def load_stock_transaction_history(self, path):
        # ASsume column names are correct:
        ## Symbol, Security, Qt, Type, Open date, Adj cost per share, Adj cost
        
        # Read pandas from path / csv / Excel
        filetype = re.findall("\.\w{2,4}$",path)[0]
        if filetype == ".csv":
            temp_df = pd.read_csv(path)
        elif filetype == [".xlsx",".xlsm",".xls"]:
            temp_df = pd.read_excel(path)
        else:
            print(f"LoadError: are you sure the path {path} is correct? Make sure your file is in the correct format.")
        
        # Include basic statistics
        temp_df['Open date'] = pd.to_datetime(temp_df['Open date'])
        temp_df['Cost_per_share'] = temp_df['Adj cost per share']
        temp_df = temp_df[temp_df['Symbol']==self._stock.symbol].reset_index(drop=True)
        temp_df['Date'] = pd.to_datetime(temp_df['Open date'])
        temp_df = temp_df[['Qty','Date','Type','Cost_per_share']]
        temp_df = temp_df.set_index("Date")
        
        # Minimum date
        first_buy = min(temp_df.index)
        # Create dataframe with dates starting at the earlier purchase (minimum date)
        diary_df = self._lookup_values(self._historical_stock_data, "index", first_buy, "gt", "df")
        diary_df['Symbol'] = self._symbol
#         temp_df.drop("Symbol", axis=1)
        diary_df = diary_df.join(temp_df)
        diary_df.loc[~diary_df['Type'].str.contains("Buy",case=False,na=False),'Q_type'] = \
            diary_df.loc[~diary_df['Type'].str.contains("Buy",case=False, na=False), "Qty"]*-1
        diary_df.loc[diary_df['Q_type'].isnull(),"Q_type"] = diary_df.loc[diary_df['Q_type'].isnull(),"Qty"]
        diary_df['Shares_Owned'] = diary_df['Q_type'].fillna(0).cumsum()
#         diary_df['Equity'] = diary_df
        print(diary_df)
#         shares_owned = 0
#         for i, row in temp_df.iterrows():
#             if row['Type'] == "Buy":
#                 shares_owned = shares_owned + row['Qty']
#             elif row['Type'] == "Sell":
#                 shares_owned = shares_owned - row['Qty']
#             else:
#                 print("Unrecognized transaction type")
#             temp_df.at[i, "Owned_Shares"] = shares_owned
        
        self.transaction_history = diary_df

# %%
aapl = Stock("FB")

# %%
pos = Position(aapl)
pos.load_stock_transaction_history(transactions_path)
pos.transaction_history.Shares_Owned.plot()
# Out:
#                     FB Symbol   Qty Type  Cost_per_share  Q_type  Shares_Owned
# Date
# 2014-01-06   57.200001     FB  60.0  Buy           54.79    60.0          60.0
# 2014-01-07   57.919998     FB   NaN  NaN             NaN     NaN          60.0
# 2014-01-08   58.230000     FB   NaN  NaN             NaN     NaN          60.0
# 2014-01-09   57.220001     FB   NaN  NaN             NaN     NaN          60.0
# 2014-01-10   57.939999     FB   NaN  NaN             NaN     NaN          60.0
# ...                ...    ...   ...  ...             ...     ...           ...
# 2020-10-05  264.649994     FB   NaN  NaN             NaN     NaN          81.0
# 2020-10-06  258.660004     FB   NaN  NaN             NaN     NaN          81.0
# 2020-10-07  258.119995     FB   NaN  NaN             NaN     NaN          81.0
# 2020-10-08  263.760010     FB   NaN  NaN             NaN     NaN          81.0
# 2020-10-09  264.450012     FB   NaN  NaN             NaN     NaN          81.0
#
# [1704 rows x 7 columns]

# %%
pos.buy(10, "2017-09-27")

# %%
pos.transaction_history.rolling(30, min_periods=1).mean().plot()
